# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np

# %%
filename = 'n10000s1.csv'
title = ' sigma=1'

# %%
def summary(df, format='df'):
    stats = {}
    for cname in df.columns:
        values = df.loc[:,cname].values
        try:
            _means = np.mean(values)
            _vars = np.var(values)
            _maxs = np.max(values)
            _mins = np.min(values)
        except Exception:
            _means = _vars = _maxs = _mins = np.NAN
        stat = {'mean': _means,
                'var': _vars,
                'min': _mins,
                'max': _maxs
                }
        stats[cname] = stat
    if format == 'df':
        import pandas as pd
        df = pd.DataFrame(stats).transpose()
        return df
    else:
        return stats

# %%
df_s1 = pd.read_csv(filename)
df_s1 = df_s1.drop(columns=['ID'])
df_s1.dropna(axis = 0, how ='any', thresh = None, subset = None, inplace=False)
s = summary(df_s1)
s.sort_values('var',ascending=False)
# Out:
#                      mean           var           min       max
# vG6PDH       1.169697e-01  8.493351e-03  1.840000e-06  0.499985
# vPGDH        1.169260e-01  8.486756e-03  1.830000e-06  0.499767
# vGAPDH       2.959420e-01  8.004544e-03  1.404601e-04  0.398380
# vPGK         2.959418e-01  8.004537e-03  1.404601e-04  0.398377
# vPGI         6.565501e-02  7.682136e-03 -2.996220e-01  0.195852
# vrpGluMu     2.788524e-01  7.292244e-03  1.404556e-04  0.391482
# vENO         2.788454e-01  7.291950e-03  1.404556e-04  0.391477
# vPDH         1.593701e-01  6.611934e-03  0.000000e+00  0.356912
# vSynth2      6.989730e-02  4.034533e-03  9.456140e-04  0.369265
# vRu5P        6.807664e-02  3.925381e-03 -5.874606e-02  0.332630
# vEXTER       1.852782e-01  2.727640e-03  1.404556e-04  0.200504
# vPTS         1.852782e-01  2.727640e-03  1.404556e-04  0.200504
# vPFK         1.322809e-01  2.200835e-03  0.000000e+00  0.196949
# vALDO        1.322747e-01  2.200604e-03  0.000000e+00  0.196951
# vTIS         1.304339e-01  2.156336e-03 -3.280000e-07  0.196726
# vPK          3.854224e-02  1.158288e-03  0.000000e+00  0.178295
# vTKB         3.145942e-02  1.029912e-03 -3.846939e-02  0.166203
# vR5PI        4.884671e-02  9.710156e-04  1.830000e-06  0.173755
# vTA          3.658162e-02  9.611471e-04 -2.908620e-02  0.166402
# vTKA         3.661410e-02  9.598059e-04 -2.908361e-02  0.166424
# vpepCxylase  3.575357e-02  9.220471e-04  0.000000e+00  0.160221
# vsersynth    1.705182e-02  3.485655e-04  4.330000e-09  0.152820
# vSynth1      1.410413e-02  2.493639e-04  0.000000e+00  0.150531
# vPPK         1.222384e-02  1.507050e-04  1.820000e-06  0.107654
# vDAHPS       5.120380e-03  5.430348e-05  0.000000e+00  0.053990
# vMethSynth   3.771280e-03  2.395631e-05  4.550000e-05  0.087530
# vPGM         2.574641e-03  1.350214e-05  1.710000e-09  0.040387
# vG1PAT       2.560228e-03  1.349493e-05  1.610000e-09  0.040381
# vG3PDH       1.837373e-03  8.729480e-06  0.000000e+00  0.055866
# vTRPSYNTH    1.745513e-03  4.745691e-06  1.950000e-05  0.032459
# vMURSyNTH    7.007723e-04  8.181950e-07  8.680000e-06  0.020296
# vPG          4.368872e-05  3.790322e-07  0.000000e+00  0.058081
# vSED7P       3.252407e-05  4.352321e-08  0.000000e+00  0.007406
# vpyr         6.989553e-05  3.056408e-08  9.760000e-08  0.016675
# vPEP         4.681653e-05  3.131006e-09  0.000000e+00  0.000996
# vPG3         3.762416e-05  2.015304e-09  0.000000e+00  0.000804
# vG6P         7.892146e-05  1.325052e-09  0.000000e+00  0.000558
# vpg2         7.024085e-06  7.034031e-11  0.000000e+00  0.000149
# vfdP         6.272938e-06  5.788452e-11  0.000000e+00  0.000057
# vGLP         1.441238e-05  4.271914e-11  0.000000e+00  0.000106
# vf6P         1.360461e-05  3.931480e-11  0.000000e+00  0.000096
# vRIB5P       8.737199e-06  2.123031e-11  0.000000e+00  0.000059
# vGAP         4.021628e-06  1.142548e-11  0.000000e+00  0.000016
# vDHAP        3.269773e-06  6.822321e-12  0.000000e+00  0.000018
# vXYL5P       3.084688e-06  2.255449e-12  0.000000e+00  0.000020
# vRibu5p      2.650107e-06  1.769853e-12  0.000000e+00  0.000016
# vE4P         1.794408e-06  1.433715e-12  0.000000e+00  0.000006
# vPGP         1.424958e-07  2.857699e-14  0.000000e+00  0.000003

# %%
x = df_s1.loc[:, :].values
x = StandardScaler(with_mean=False).fit_transform(x)
pca1 = PCA(n_components=2)
principalComponents1 = pca1.fit_transform(x)
pca1.explained_variance_ratio_
df_s1.loc[:,df_s1.columns[0]].values
# Out:
# array([0.20045633, 0.20044869, 0.20045943, ..., 0.20037007, 0.20031815,
#        0.20046209])

# %%
pc_s1 = pd.DataFrame(data = principalComponents1
             , columns = [ 'PC1', 'PC2'])
pc_s1
# Out:
#             PC1       PC2
# 0      0.572219 -0.795797
# 1     -0.391285  3.321088
# 2     -0.479992 -1.191521
# 3      1.948303  0.896778
# 4     23.404223  2.901846
# ...         ...       ...
# 9317  -0.253264 -2.190660
# 9318  -0.643180 -0.987808
# 9319   0.831231  1.224912
# 9320   4.265996 -0.197625
# 9321   1.007800 -2.650368
#
# [9322 rows x 2 columns]

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA'+title, fontsize = 20)
ax.scatter(pc_s1.loc[:, 'PC1'],
           pc_s1.loc[:, 'PC2'])
ax.grid()
